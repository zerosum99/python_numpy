# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.15.4'

# %% [markdown]
# ## 복소수로 배열 생성

# %%
b = np.array([1.j + 3, 2.j + 4])

# %%
b
# Out:
# array([3.+1.j, 4.+2.j])

# %%
b.real
# Out:
# array([3., 4.])

# %%
b.imag
# Out:
# array([1., 2.])

# %% [markdown]
# ### 배열의 자료형 확인하기

# %%
b.dtype
# Out:
# dtype('complex128')

# %%
b.dtype.str
# Out:
# '<c16'

# %%
b.dtype.char
# Out:
# 'D'

# %% [markdown]
# ## 배열의 데이터 확인하기

# %%
b
# Out:
# array([3.+1.j, 4.+2.j])

# %%
b.flat

# %%
b.flat[0]
# Out:
# (3+1j)
